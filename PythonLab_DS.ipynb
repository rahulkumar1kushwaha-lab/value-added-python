# %%
# This program prints an institute name
print("hello Welcome to Gulzar College of Institutions, NAAC A+")
# Out:
# hello Welcome to Gulzar College of Institutions, NAAC A+

# %%
# Welcome user
name = input("Enter your name: ")
print("Welcome", name)
# Out:
# Enter your name:  Rahul
# Welcome Rahul

# %%
# Syntax & indentation correction
# Corrected code
if 5 > 2:
    print("Five is greater than two")
# Out:
# Five is greater than two

# %%
#Largest of three numbers
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter c: "))

if a > b and a > c:
    print("Largest:", a)
elif b > c:
    print("Largest:", b)
else:
    print("Largest:", c)
# Out:
# Enter a:  25
# Enter b:  45
# Enter c:  56
# Largest: 56

# %%
## Menu-driven calculator
a =int(input("Enter the first number:"))
b =int(input("Enter the second number:"))
print("1.ADD,2.sub,3.mul,4.divi")
ch = int(input(" as you like:"))

if ch == 1:
    print(a+b)
elif ch== 2:
    print(a-b)
elif ch== 3:
    
    print(a*b)
elif ch== 4:
    print(a/b)
else:
    print("It is not valide:")
# Out:
# Enter the first number: 6
# Enter the second number: 6
# 1.ADD,2.sub,3.mul,4.divi
#  as you like: 3
# 36

# %%
## Question no:01 write a python programme to eligibility to check problem
age = 18 
age = int(input("Enter your age:"))
if age<0:
    print("can't take vote")
elif age<=18:
    print("you can vote:")
else:
    print("you are not eligible ")
# Out:
# Enter your age: 18
# you can vote:

# %%
# write a python programme to fibonacci series

n = int(input("Enter the value:"))  
a = 0 
b = 1 
print("Fibonacci series")

for i in range(n): 
    print(a, end=" ")
    c = a + b 
    a = b
    b = c
# Out:
# Enter the value: 5
# Fibonacci series
# 0 1 1 2 3

# %%
# write a  python programme to print a factorial programme
import math

num = int(input("Enter the number: "))
print(f"Factorial of {num} is {math.factorial(num)}")
# Out:
# Enter the number:  5
# Factorial of 5 is 120
